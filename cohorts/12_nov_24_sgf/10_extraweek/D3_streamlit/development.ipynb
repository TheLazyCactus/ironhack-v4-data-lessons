# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [X-y split](#toc1_)
# - [Encoding categoricals & scaling numericals](#toc2_)
# - [Train-test split](#toc3_)
# - [Model](#toc4_)
# - [Save models](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# !pip install plotly
import plotly.express as px

# %%
import pandas as pd
import numpy as np
import pickle
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/sabinagio/data-analytics/main/data/customer_churn.csv").dropna()
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
px.histogram(x=data.MonthlyCharges, facet_row=data.Churn)

# %%
data.drop('customerID', axis=1, inplace=True)

# %%
data.shape
# Out:
# (7032, 20)

# %% [markdown]
# # <a id='toc1_'></a>[X-y split](#toc0_)

# %%
X = data.drop('Churn', axis=1)
y = data['Churn']

# %% [markdown]
# # <a id='toc2_'></a>[Encoding categoricals & scaling numericals](#toc0_)

# %%
num_data = X.select_dtypes(np.number)
cat_data = X.select_dtypes(object)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_data_scaled = pd.DataFrame(scaler.fit_transform(num_data), columns=scaler.get_feature_names_out())
num_data_scaled
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 0               0.0  0.000000        0.115423      0.001275
# 1               0.0  0.464789        0.385075      0.215867
# 2               0.0  0.014085        0.354229      0.010310
# 3               0.0  0.619718        0.239303      0.210241
# 4               0.0  0.014085        0.521891      0.015330
# ...             ...       ...             ...           ...
# 7027            0.0  0.323944        0.662189      0.227521
# 7028            0.0  1.000000        0.845274      0.847461
# 7029            0.0  0.140845        0.112935      0.037809
# 7030            1.0  0.042254        0.558706      0.033210
# 7031            0.0  0.915493        0.869652      0.787641
#
# [7032 rows x 4 columns]

# %%
cat_data_encoded = pd.get_dummies(cat_data).reset_index(drop=True)
cat_data_encoded
# Out:
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  \
# 0              True        False       False         True           True
# 1             False         True        True        False           True
# 2             False         True        True        False           True
# 3             False         True        True        False           True
# 4              True        False        True        False           True
# ...             ...          ...         ...          ...            ...
# 7027          False         True       False         True          False
# 7028           True        False       False         True          False
# 7029           True        False       False         True          False
# 7030          False         True       False         True           True
# 7031          False         True        True        False           True
#
#       Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0              False             True             False             False
# 1              False            False              True              True
# 2              False            False              True              True
# 3              False             True             False             False
# 4              False            False              True              True
# ...              ...              ...               ...               ...
# 7027            True            False              True             False
# 7028            True            False              True             False
# 7029            True             True             False             False
# 7030           False            False              True             False
# 7031           False            False              True              True
#
#       MultipleLines_No phone service  MultipleLines_Yes  InternetService_DSL  \
# 0                               True              False                 True
# 1                              False              False                 True
# 2                              False              False                 True
# 3                               True              False                 True
# 4                              False              False                False
# ...                              ...                ...                  ...
# 7027                           False               True                 True
# 7028                           False               True                False
# 7029                            True              False                 True
# 7030                           False               True                False
# 7031                           False              False                False
#
#       InternetService_Fiber optic  InternetService_No  OnlineSecurity_No  \
# 0                           False               False               True
# 1                           False               False              False
# 2                           False               False              False
# 3                           False               False              False
# 4                            True               False               True
# ...                           ...                 ...                ...
# 7027                        False               False              False
# 7028                         True               False               True
# 7029                        False               False              False
# 7030                         True               False               True
# 7031                         True               False              False
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  OnlineBackup_No  \
# 0                                  False               False            False
# 1                                  False                True             True
# 2                                  False                True            False
# 3                                  False                True             True
# 4                                  False               False             True
# ...                                  ...                 ...              ...
# 7027                               False                True             True
# 7028                               False               False            False
# 7029                               False                True             True
# 7030                               False               False             True
# 7031                               False                True             True
#
#       OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No  \
# 0                                False              True                 True
# 1                                False             False                False
# 2                                False              True                 True
# 3                                False             False                False
# 4                                False             False                 True
# ...                                ...               ...                  ...
# 7027                             False             False                False
# 7028                             False              True                False
# 7029                             False             False                 True
# 7030                             False             False                 True
# 7031                             False             False                False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 7027                                 False                  True
# 7028                                 False                  True
# 7029                                 False                 False
# 7030                                 False                 False
# 7031                                 False                  True
#
#       TechSupport_No  TechSupport_No internet service  TechSupport_Yes  \
# 0               True                            False            False
# 1               True                            False            False
# 2               True                            False            False
# 3              False                            False             True
# 4               True                            False            False
# ...              ...                              ...              ...
# 7027           False                            False             True
# 7028            True                            False            False
# 7029            True                            False            False
# 7030            True                            False            False
# 7031           False                            False             True
#
#       StreamingTV_No  StreamingTV_No internet service  StreamingTV_Yes  \
# 0               True                            False            False
# 1               True                            False            False
# 2               True                            False            False
# 3               True                            False            False
# 4               True                            False            False
# ...              ...                              ...              ...
# 7027           False                            False             True
# 7028           False                            False             True
# 7029            True                            False            False
# 7030            True                            False            False
# 7031           False                            False             True
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 0                   True                                False
# 1                   True                                False
# 2                   True                                False
# 3                   True                                False
# 4                   True                                False
# ...                  ...                                  ...
# 7027               False                                False
# 7028               False                                False
# 7029                True                                False
# 7030                True                                False
# 7031               False                                False
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                   False                     True              False
# 1                   False                    False               True
# 2                   False                     True              False
# 3                   False                    False               True
# 4                   False                     True              False
# ...                   ...                      ...                ...
# 7027                 True                    False               True
# 7028                 True                    False               True
# 7029                False                     True              False
# 7030                False                     True              False
# 7031                 True                    False              False
#
#       Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                 False                False                  True
# 1                 False                 True                 False
# 2                 False                False                  True
# 3                 False                 True                 False
# 4                 False                False                  True
# ...                 ...                  ...                   ...
# 7027              False                False                  True
# 7028              False                False                  True
# 7029              False                False                  True
# 7030              False                False                  True
# 7031               True                False                  True
#
#       PaymentMethod_Bank transfer (automatic)  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                       False
# ...                                       ...
# 7027                                    False
# 7028                                    False
# 7029                                    False
# 7030                                    False
# 7031                                     True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                            True
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                            True
# ...                                     ...                             ...
# 7027                                  False                           False
# 7028                                   True                           False
# 7029                                  False                            True
# 7030                                  False                           False
# 7031                                  False                           False
#
#       PaymentMethod_Mailed check
# 0                          False
# 1                           True
# 2                           True
# 3                          False
# 4                          False
# ...                          ...
# 7027                        True
# 7028                       False
# 7029                       False
# 7030                        True
# 7031                       False
#
# [7032 rows x 41 columns]

# %%
X_prep = pd.concat([num_data_scaled, cat_data_encoded], axis=1)
X_prep
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0               0.0  0.000000        0.115423      0.001275           True
# 1               0.0  0.464789        0.385075      0.215867          False
# 2               0.0  0.014085        0.354229      0.010310          False
# 3               0.0  0.619718        0.239303      0.210241          False
# 4               0.0  0.014085        0.521891      0.015330           True
# ...             ...       ...             ...           ...            ...
# 7027            0.0  0.323944        0.662189      0.227521          False
# 7028            0.0  1.000000        0.845274      0.847461           True
# 7029            0.0  0.140845        0.112935      0.037809           True
# 7030            1.0  0.042254        0.558706      0.033210          False
# 7031            0.0  0.915493        0.869652      0.787641          False
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 0           False       False         True           True           False
# 1            True        True        False           True           False
# 2            True        True        False           True           False
# 3            True        True        False           True           False
# 4           False        True        False           True           False
# ...           ...         ...          ...            ...             ...
# 7027         True       False         True          False            True
# 7028        False       False         True          False            True
# 7029        False       False         True          False            True
# 7030         True       False         True           True           False
# 7031         True        True        False           True           False
#
#       PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0                True             False             False
# 1               False              True              True
# 2               False              True              True
# 3                True             False             False
# 4               False              True              True
# ...               ...               ...               ...
# 7027            False              True             False
# 7028            False              True             False
# 7029             True             False             False
# 7030            False              True             False
# 7031            False              True              True
#
#       MultipleLines_No phone service  MultipleLines_Yes  InternetService_DSL  \
# 0                               True              False                 True
# 1                              False              False                 True
# 2                              False              False                 True
# 3                               True              False                 True
# 4                              False              False                False
# ...                              ...                ...                  ...
# 7027                           False               True                 True
# 7028                           False               True                False
# 7029                            True              False                 True
# 7030                           False               True                False
# 7031                           False              False                False
#
#       InternetService_Fiber optic  InternetService_No  OnlineSecurity_No  \
# 0                           False               False               True
# 1                           False               False              False
# 2                           False               False              False
# 3                           False               False              False
# 4                            True               False               True
# ...                           ...                 ...                ...
# 7027                        False               False              False
# 7028                         True               False               True
# 7029                        False               False              False
# 7030                         True               False               True
# 7031                         True               False              False
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  OnlineBackup_No  \
# 0                                  False               False            False
# 1                                  False                True             True
# 2                                  False                True            False
# 3                                  False                True             True
# 4                                  False               False             True
# ...                                  ...                 ...              ...
# 7027                               False                True             True
# 7028                               False               False            False
# 7029                               False                True             True
# 7030                               False               False             True
# 7031                               False                True             True
#
#       OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No  \
# 0                                False              True                 True
# 1                                False             False                False
# 2                                False              True                 True
# 3                                False             False                False
# 4                                False             False                 True
# ...                                ...               ...                  ...
# 7027                             False             False                False
# 7028                             False              True                False
# 7029                             False             False                 True
# 7030                             False             False                 True
# 7031                             False             False                False
#
#       DeviceProtection_No internet service  DeviceProtection_Yes  \
# 0                                    False                 False
# 1                                    False                  True
# 2                                    False                 False
# 3                                    False                  True
# 4                                    False                 False
# ...                                    ...                   ...
# 7027                                 False                  True
# 7028                                 False                  True
# 7029                                 False                 False
# 7030                                 False                 False
# 7031                                 False                  True
#
#       TechSupport_No  TechSupport_No internet service  TechSupport_Yes  \
# 0               True                            False            False
# 1               True                            False            False
# 2               True                            False            False
# 3              False                            False             True
# 4               True                            False            False
# ...              ...                              ...              ...
# 7027           False                            False             True
# 7028            True                            False            False
# 7029            True                            False            False
# 7030            True                            False            False
# 7031           False                            False             True
#
#       StreamingTV_No  StreamingTV_No internet service  StreamingTV_Yes  \
# 0               True                            False            False
# 1               True                            False            False
# 2               True                            False            False
# 3               True                            False            False
# 4               True                            False            False
# ...              ...                              ...              ...
# 7027           False                            False             True
# 7028           False                            False             True
# 7029            True                            False            False
# 7030            True                            False            False
# 7031           False                            False             True
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 0                   True                                False
# 1                   True                                False
# 2                   True                                False
# 3                   True                                False
# 4                   True                                False
# ...                  ...                                  ...
# 7027               False                                False
# 7028               False                                False
# 7029                True                                False
# 7030                True                                False
# 7031               False                                False
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                   False                     True              False
# 1                   False                    False               True
# 2                   False                     True              False
# 3                   False                    False               True
# 4                   False                     True              False
# ...                   ...                      ...                ...
# 7027                 True                    False               True
# 7028                 True                    False               True
# 7029                False                     True              False
# 7030                False                     True              False
# 7031                 True                    False              False
#
#       Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                 False                False                  True
# 1                 False                 True                 False
# 2                 False                False                  True
# 3                 False                 True                 False
# 4                 False                False                  True
# ...                 ...                  ...                   ...
# 7027              False                False                  True
# 7028              False                False                  True
# 7029              False                False                  True
# 7030              False                False                  True
# 7031               True                False                  True
#
#       PaymentMethod_Bank transfer (automatic)  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                       False
# ...                                       ...
# 7027                                    False
# 7028                                    False
# 7029                                    False
# 7030                                    False
# 7031                                     True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                            True
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                            True
# ...                                     ...                             ...
# 7027                                  False                           False
# 7028                                   True                           False
# 7029                                  False                            True
# 7030                                  False                           False
# 7031                                  False                           False
#
#       PaymentMethod_Mailed check
# 0                          False
# 1                           True
# 2                           True
# 3                          False
# 4                          False
# ...                          ...
# 7027                        True
# 7028                       False
# 7029                       False
# 7030                        True
# 7031                       False
#
# [7032 rows x 45 columns]

# %% [markdown]
# # <a id='toc3_'></a>[Train-test split](#toc0_)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_prep, y, random_state=42, test_size=0.3)

# %% [markdown]
# # <a id='toc4_'></a>[Model](#toc0_)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
log_model = LogisticRegression()
knn_model = KNeighborsClassifier()
bayes_model = MultinomialNB()

# %%
# After we're satisfied with our models we can fit on the whole dataset
log_model.fit(X, y)
knn_model.fit(X, y)
bayes_model.fit(X, y)
# Out:
# MultinomialNB()

# %%
# We will revisit these metrics in one of the AI classes
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

pred = log_model.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.86      1549
#          Yes       0.64      0.53      0.58       561
#
#     accuracy                           0.80      2110
#    macro avg       0.74      0.71      0.72      2110
# weighted avg       0.79      0.80      0.79      2110

# %%
pred = knn_model.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.84      0.84      1549
#          Yes       0.54      0.52      0.53       561
#
#     accuracy                           0.76      2110
#    macro avg       0.69      0.68      0.68      2110
# weighted avg       0.75      0.76      0.75      2110

# %%
pred = bayes_model.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.91      0.67      0.77      1549
#          Yes       0.47      0.81      0.60       561
#
#     accuracy                           0.71      2110
#    macro avg       0.69      0.74      0.69      2110
# weighted avg       0.79      0.71      0.73      2110

# %% [markdown]
# # <a id='toc5_'></a>[Save models](#toc0_)

# %%
# creating pickle files (saving the models)
with open("models/log_reg.pkl", "wb") as li:  # wb: mode write
    pickle.dump(log_model, li)

with open("models/knn.pkl", "wb") as lo:
    pickle.dump(knn_model, lo)

with open("models/bayes.pkl", "wb") as sv:
    pickle.dump(bayes_model, sv)

# %%
with open("prep/scaler.pkl", "wb") as sc:
    pickle.dump(scaler, sc)
