# %% [markdown]
# ## Machine Learning Supervised

# %% [markdown]
# So far, we have focused on using KNN as our model to predict California housing prices. However, there are other models worth exploring. Today, we will experiment with both simple Linear Regression and Decision Trees to understand how they explain our target variable. In machine learning, we typically choose our model based on the relationship between our features and the target variable, or simply by selecting the model with the higher score

# %% [markdown]
# Yesterday, we applied some feature engineering techniques, and our model indeed increased its performance. Now, let's see how Linear Regression and Decision Tree perform when we apply the same feature engineering techniques.

# %% [markdown]
# #### Loading and preparing the data

# %%
from sklearn.datasets import  fetch_california_housing
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
california = fetch_california_housing()
print(california["DESCR"])
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
df_cali = pd.DataFrame(california["data"], columns = california["feature_names"])
df_cali["median_house_value"] = california["target"]

df_cali.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  median_house_value
# 0    -122.23               4.526
# 1    -122.22               3.585
# 2    -122.24               3.521
# 3    -122.25               3.413
# 4    -122.25               3.422

# %% [markdown]
# #### Normalization & Feature Selection

# %% [markdown]
# Like we did in Feature Engineering lesson, we are going to normalize our data and select a subset of columns as our features.

# %% [markdown]
# #### Train Test Split

# %%
#your code here
X_train, X_test, y_train, y_test = train_test_split(df_cali.drop(columns='median_house_value'), df_cali['median_house_value'], test_size=0.2, random_state=42)

# %% [markdown]
# Create an instance of the normalizer

# %%
#your code here
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_norm, X_test_norm = scaler.transform(X_train), scaler.transform(X_test)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Let's create an instance of Linear Regression model.

# %%
#your code here
lr = LinearRegression()
lr_norm = LinearRegression()

# %% [markdown]
# Training Linear Regression with our normalized data

# %%
#your code here
lr.fit(X_train, y_train)
lr_norm.fit(X_train_norm, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluate model's performance

# %%
#your code here
print("Original:", lr.score(X_test, y_test))
print("Scaled:", lr_norm.score(X_test_norm, y_test))
# Out:
# Original: 0.5757877060324511
# Normalized: 0.5757877060324512

# %%
import plotly.express as px

px.bar(y=lr.feature_names_in_, x=lr.coef_)

# %% [markdown]
# Linear Regression yielding a worse score than our previous model, KNN.

# %% [markdown]
# In Linear Regression, we often assess feature importance by examining the coefficients in the model. These coefficients indicate the impact of each feature on the model's predictions.

# %% [markdown]
# - Determine the coefficients (β) in the linear regression equation corresponding to each feature.
# - The magnitude of these coefficients reflects the relative importance of the features. **Greater absolute values suggest more substantial impacts.**

# %%
#your code here

# %% [markdown]
# We can conclude that **Median Income** have the highest impact in our model.

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# So far between KNN and Liner Regression, the first yield a better score, let's see how a Decision Tree performs.

# %% [markdown]
# - Initialize a Decision Tree instance
#
# - Setting max_depth as 10, this means we will allow our tree to split 10 times

# %%
#your code here
dt = DecisionTreeRegressor()
dt_norm = DecisionTreeRegressor()

# %% [markdown]
# - Training the model

# %%
#your code here
dt.fit(X_train, y_train)
dt_norm.fit(X_train_norm, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# - Evaluate the model

# %%
#your code here
print("Original:", dt.score(X_test, y_test))
print("Scaled:", dt_norm.score(X_test_norm, y_test))
# Out:
# Original: 0.617014267613832
# Scaled: 0.6097898848011593

# %% [markdown]
# Often we check what are the most relevant features, like we did before in Linear Regression.

# %%
#your code here     
px.bar(y=dt.feature_names_in_, x=dt.feature_importances_)

# %%
from sklearn.tree import export_text

tree_viz = export_text(dt, feature_names=dt.feature_names_in_)
print(tree_viz)
# Out:
# |--- MedInc <= 5.09
# |   |--- MedInc <= 3.07
# |   |   |--- AveRooms <= 4.31
# |   |   |   |--- MedInc <= 2.21
# |   |   |   |   |--- AveRooms <= 3.42
# |   |   |   |   |   |--- AveBedrms <= 1.03
# |   |   |   |   |   |   |--- Longitude <= -121.83
# |   |   |   |   |   |   |   |--- Longitude <= -121.96
# |   |   |   |   |   |   |   |   |--- AveOccup <= 4.20
# |   |   |   |   |   |   |   |   |   |--- Population <= 1692.50
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Population >  1692.50
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 2290.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Population >  2290.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |--- AveOccup >  4.20
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.62]
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |--- Longitude >  -121.96
# |   |   |   |   |   |   |   |   |--- MedInc <= 1.93
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |--- MedInc >  1.93
# |   |   |   |   |   |   |   |   |   |--- value: [2.31]
# |   |   |   |   |   |   |--- Longitude >  -121.83
# |   |   |   |   |   |   |   |--- Latitude <= 35.34
# |   |   |   |   |   |   |   |   |--- Longitude <= -118.30
# |   |   |   |   |   |   |   |   |   |--- Population <= 1150.50
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Population >  1150.50
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Longitude >  -118.30
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.33
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 4.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  4.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.33
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 3.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  3.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- Latitude >  35.34
# |   |   |   |   |   |   |   |   |--- MedInc <= 1.12
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 19.50
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 38.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  38.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  19.50
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.90]
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- MedInc >  1.12
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.03
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.21]
# |   |   |   |   |   |--- AveBedrms >  1.03
# |   |   |   |   |   |   |--- Latitude <= 34.05
# |   |   |   |   |   |   |   |--- MedInc <= 0.76
# |   |   |   |   |   |   |   |   |--- AveOccup <= 7.17
# |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |--- AveOccup >  7.17
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |--- MedInc >  0.76
# |   |   |   |   |   |   |   |   |--- Longitude <= -117.15
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  33.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 316.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Population >  316.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- Longitude >  -117.15
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 32.77
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Latitude >  32.77
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |--- Latitude >  34.05
# |   |   |   |   |   |   |   |--- Latitude <= 37.92
# |   |   |   |   |   |   |   |   |--- AveOccup <= 3.17
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.75
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- MedInc >  1.75
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- AveOccup >  3.17
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 4.37
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 4.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  4.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  4.37
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |   |   |   |--- Latitude >  37.92
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.13
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 38.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.88]
# |   |   |   |   |   |   |   |   |   |--- Latitude >  38.16
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 3.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  3.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.13
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.18
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MedInc >  1.18
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- AveRooms >  3.42
# |   |   |   |   |   |--- AveOccup <= 2.11
# |   |   |   |   |   |   |--- AveBedrms <= 1.41
# |   |   |   |   |   |   |   |--- Longitude <= -121.86
# |   |   |   |   |   |   |   |   |--- Latitude <= 36.61
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |--- Latitude >  36.61
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 40.00
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Latitude >  40.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |   |   |   |--- Longitude >  -121.86
# |   |   |   |   |   |   |   |   |--- AveRooms <= 4.30
# |   |   |   |   |   |   |   |   |   |--- Population <= 1517.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- Population >  1517.00
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 1624.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.67]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  1624.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- AveRooms >  4.30
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.46
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.27]
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.46
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.40]
# |   |   |   |   |   |   |--- AveBedrms >  1.41
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |--- AveOccup >  2.11
# |   |   |   |   |   |   |--- Latitude <= 35.31
# |   |   |   |   |   |   |   |--- Longitude <= -117.81
# |   |   |   |   |   |   |   |   |--- AveOccup <= 3.43
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.02
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.02
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- AveOccup >  3.43
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.41
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.41
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |--- Longitude >  -117.81
# |   |   |   |   |   |   |   |   |--- Longitude <= -116.58
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 5.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  5.56
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.19]
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  34.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- Longitude >  -116.58
# |   |   |   |   |   |   |   |   |   |--- Population <= 869.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 3.27
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  3.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Population >  869.00
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 2474.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Population >  2474.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Latitude >  35.31
# |   |   |   |   |   |   |   |--- Longitude <= -121.56
# |   |   |   |   |   |   |   |   |--- Latitude <= 39.12
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 8.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.10]
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  8.00
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- Latitude >  39.12
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.25]
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- Longitude >  -121.56
# |   |   |   |   |   |   |   |   |--- Longitude <= -120.47
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.73
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.73
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- Longitude >  -120.47
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 0.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.12]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  0.77
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 37.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  37.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- MedInc >  2.21
# |   |   |   |   |--- AveOccup <= 2.49
# |   |   |   |   |   |--- Longitude <= -118.26
# |   |   |   |   |   |   |--- Latitude <= 37.82
# |   |   |   |   |   |   |   |--- AveOccup <= 1.77
# |   |   |   |   |   |   |   |   |--- MedInc <= 2.26
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 0.89
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.75]
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  0.89
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |   |   |--- MedInc >  2.26
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 1.49
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  1.49
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 3.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  3.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- AveOccup >  1.77
# |   |   |   |   |   |   |   |   |--- Longitude <= -122.37
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.27
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.27
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.90]
# |   |   |   |   |   |   |   |   |--- Longitude >  -122.37
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.63
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- Latitude >  34.63
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 211.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  211.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |--- Latitude >  37.82
# |   |   |   |   |   |   |   |--- Longitude <= -122.05
# |   |   |   |   |   |   |   |   |--- MedInc <= 2.42
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.11]
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.06
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.69]
# |   |   |   |   |   |   |   |   |--- MedInc >  2.42
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.07
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.07
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- Longitude >  -122.05
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.11
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.07
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 38.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.12]
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  38.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.07
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.11
# |   |   |   |   |   |   |   |   |   |--- Population <= 885.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.52]
# |   |   |   |   |   |   |   |   |   |--- Population >  885.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- Longitude >  -118.26
# |   |   |   |   |   |   |--- Longitude <= -117.15
# |   |   |   |   |   |   |   |--- AveBedrms <= 1.22
# |   |   |   |   |   |   |   |   |--- HouseAge <= 26.50
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 1.56
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.69
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.68]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  1.56
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.48
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |--- HouseAge >  26.50
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.77
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Latitude >  33.77
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.69
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.16]
# |   |   |   |   |   |   |   |--- AveBedrms >  1.22
# |   |   |   |   |   |   |   |   |--- AveOccup <= 2.08
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.17
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.41
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.40]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.41
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |   |   |--- AveOccup >  2.08
# |   |   |   |   |   |   |   |   |   |--- value: [2.18]
# |   |   |   |   |   |   |--- Longitude >  -117.15
# |   |   |   |   |   |   |   |--- AveBedrms <= 0.91
# |   |   |   |   |   |   |   |   |--- value: [2.69]
# |   |   |   |   |   |   |   |--- AveBedrms >  0.91
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.12
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.36
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 2427.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Population >  2427.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.52]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.36
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 32.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  32.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.12
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 32.84
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Latitude >  32.84
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -116.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -116.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |--- AveOccup >  2.49
# |   |   |   |   |   |--- AveOccup <= 3.47
# |   |   |   |   |   |   |--- Population <= 79.00
# |   |   |   |   |   |   |   |--- Population <= 33.00
# |   |   |   |   |   |   |   |   |--- AveRooms <= 2.10
# |   |   |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |   |   |--- AveRooms >  2.10
# |   |   |   |   |   |   |   |   |   |--- value: [1.50]
# |   |   |   |   |   |   |   |--- Population >  33.00
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.02
# |   |   |   |   |   |   |   |   |   |--- Population <= 49.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |--- Population >  49.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.02
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.52
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.25]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.52
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |--- Population >  79.00
# |   |   |   |   |   |   |   |--- Longitude <= -117.81
# |   |   |   |   |   |   |   |   |--- Latitude <= 34.65
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.23
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.23
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 511.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.55]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  511.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- Latitude >  34.65
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.38
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.29
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.75]
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.38
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -121.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -121.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- Longitude >  -117.81
# |   |   |   |   |   |   |   |   |--- HouseAge <= 6.50
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.47]
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [2.16]
# |   |   |   |   |   |   |   |   |--- HouseAge >  6.50
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.76
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 32.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  32.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.76
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- AveOccup >  3.47
# |   |   |   |   |   |   |--- Longitude <= -117.81
# |   |   |   |   |   |   |   |--- AveOccup <= 4.01
# |   |   |   |   |   |   |   |   |--- AveRooms <= 2.85
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 2.81
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  2.81
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.35
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.82]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.35
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |--- AveRooms >  2.85
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 37.56
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- Latitude >  37.56
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |--- AveOccup >  4.01
# |   |   |   |   |   |   |   |   |--- Longitude <= -121.86
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.06
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 1351.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Population >  1351.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.71]
# |   |   |   |   |   |   |   |   |--- Longitude >  -121.86
# |   |   |   |   |   |   |   |   |   |--- Population <= 2237.50
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 36.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  36.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Population >  2237.50
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.38]
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  33.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |--- Longitude >  -117.81
# |   |   |   |   |   |   |   |--- Population <= 275.50
# |   |   |   |   |   |   |   |   |--- AveRooms <= 3.62
# |   |   |   |   |   |   |   |   |   |--- value: [1.34]
# |   |   |   |   |   |   |   |   |--- AveRooms >  3.62
# |   |   |   |   |   |   |   |   |   |--- value: [1.55]
# |   |   |   |   |   |   |   |--- Population >  275.50
# |   |   |   |   |   |   |   |   |--- HouseAge <= 26.50
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 3.65
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 2039.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Population >  2039.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.50]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  3.65
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 3.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  3.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- HouseAge >  26.50
# |   |   |   |   |   |   |   |   |   |--- Population <= 2950.00
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Population >  2950.00
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.24]
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1.16]
# |   |   |--- AveRooms >  4.31
# |   |   |   |--- MedInc <= 2.42
# |   |   |   |   |--- Latitude <= 35.31
# |   |   |   |   |   |--- Longitude <= -117.35
# |   |   |   |   |   |   |--- Latitude <= 33.49
# |   |   |   |   |   |   |   |--- AveOccup <= 2.64
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.43
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 25.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  25.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.43
# |   |   |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |   |--- AveOccup >  2.64
# |   |   |   |   |   |   |   |   |--- AveRooms <= 4.45
# |   |   |   |   |   |   |   |   |   |--- value: [1.06]
# |   |   |   |   |   |   |   |   |--- AveRooms >  4.45
# |   |   |   |   |   |   |   |   |   |--- value: [1.84]
# |   |   |   |   |   |   |--- Latitude >  33.49
# |   |   |   |   |   |   |   |--- Population <= 237.50
# |   |   |   |   |   |   |   |   |--- HouseAge <= 22.50
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 1.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  1.06
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.17]
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  34.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |   |   |--- HouseAge >  22.50
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 0.83
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.75]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  0.83
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- Population >  237.50
# |   |   |   |   |   |   |   |   |--- Longitude <= -120.63
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.57
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -120.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -120.65
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.21]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.57
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.94
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.68]
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.94
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [2.47]
# |   |   |   |   |   |   |   |   |--- Longitude >  -120.63
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.31
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 35.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  35.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.31
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  33.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |--- Longitude >  -117.35
# |   |   |   |   |   |   |--- Longitude <= -116.40
# |   |   |   |   |   |   |   |--- Latitude <= 33.69
# |   |   |   |   |   |   |   |   |--- Latitude <= 32.72
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.09
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MedInc >  2.09
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 32.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  32.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- Latitude >  32.72
# |   |   |   |   |   |   |   |   |   |--- HouseAge <= 31.00
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- HouseAge >  31.00
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- Latitude >  33.69
# |   |   |   |   |   |   |   |   |--- AveOccup <= 2.40
# |   |   |   |   |   |   |   |   |   |--- Population <= 753.50
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 573.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Population >  573.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Population >  753.50
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- AveOccup >  2.40
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.02
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Latitude >  34.02
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  34.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Longitude >  -116.40
# |   |   |   |   |   |   |   |--- Population <= 17.00
# |   |   |   |   |   |   |   |   |--- value: [2.75]
# |   |   |   |   |   |   |   |--- Population >  17.00
# |   |   |   |   |   |   |   |   |--- HouseAge <= 17.50
# |   |   |   |   |   |   |   |   |   |--- Population <= 82.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Population >  82.00
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 3.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  3.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- HouseAge >  17.50
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.37
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.37
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 7.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  7.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- Latitude >  35.31
# |   |   |   |   |   |--- Latitude <= 36.85
# |   |   |   |   |   |   |--- Longitude <= -120.77
# |   |   |   |   |   |   |   |--- AveRooms <= 5.30
# |   |   |   |   |   |   |   |   |--- AveOccup <= 2.14
# |   |   |   |   |   |   |   |   |   |--- value: [2.27]
# |   |   |   |   |   |   |   |   |--- AveOccup >  2.14
# |   |   |   |   |   |   |   |   |   |--- value: [1.84]
# |   |   |   |   |   |   |   |--- AveRooms >  5.30
# |   |   |   |   |   |   |   |   |--- AveRooms <= 5.64
# |   |   |   |   |   |   |   |   |   |--- value: [1.19]
# |   |   |   |   |   |   |   |   |--- AveRooms >  5.64
# |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |--- Longitude >  -120.77
# |   |   |   |   |   |   |   |--- AveRooms <= 5.33
# |   |   |   |   |   |   |   |   |--- AveOccup <= 3.12
# |   |   |   |   |   |   |   |   |   |--- Population <= 142.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |   |   |   |--- Population >  142.00
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- AveOccup >  3.12
# |   |   |   |   |   |   |   |   |   |--- Population <= 6356.50
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- Population >  6356.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [1.06]
# |   |   |   |   |   |   |   |--- AveRooms >  5.33
# |   |   |   |   |   |   |   |   |--- AveOccup <= 3.66
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.27
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 647.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Population >  647.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.27
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- AveOccup >  3.66
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.90
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Population >  966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.90
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.69]
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |--- Latitude >  36.85
# |   |   |   |   |   |   |--- Latitude <= 38.91
# |   |   |   |   |   |   |   |--- Longitude <= -121.57
# |   |   |   |   |   |   |   |   |--- Latitude <= 37.26
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.18
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.18
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 2.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  2.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.20]
# |   |   |   |   |   |   |   |   |--- Latitude >  37.26
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.38
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.38
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |--- Longitude >  -121.57
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 16.92
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.43
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.43
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Population >  815.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.01
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- Longitude >  -121.72
# |   |   |   |   |   |   |--- Latitude <= 38.10
# |   |   |   |   |   |   |   |--- value: [1.72]
# |   |   |   |   |   |   |--- Latitude >  38.10
# |   |   |   |   |   |   |   |--- AveOccup <= 2.46
# |   |   |   |   |   |   |   |   |--- value: [2.29]
# |   |   |   |   |   |   |   |--- AveOccup >  2.46
# |   |   |   |   |   |   |   |   |--- value: [2.80]
# |   |   |--- MedInc >  7.82
# |   |   |   |--- MedInc <= 8.87
# |   |   |   |   |--- HouseAge <= 28.50
# |   |   |   |   |   |--- AveOccup <= 2.78
# |   |   |   |   |   |   |--- AveRooms <= 6.00
# |   |   |   |   |   |   |   |--- Population <= 910.50
# |   |   |   |   |   |   |   |   |--- HouseAge <= 7.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.96]
# |   |   |   |   |   |   |   |   |--- HouseAge >  7.00
# |   |   |   |   |   |   |   |   |   |--- value: [2.50]
# |   |   |   |   |   |   |   |--- Population >  910.50
# |   |   |   |   |   |   |   |   |--- value: [3.92]
# |   |   |   |   |   |   |--- AveRooms >  6.00
# |   |   |   |   |   |   |   |--- Latitude <= 37.69
# |   |   |   |   |   |   |   |   |--- HouseAge <= 18.00
# |   |   |   |   |   |   |   |   |   |--- Population <= 1554.00
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 6.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  6.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Population >  1554.00
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 8.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.21]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  8.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- HouseAge >  18.00
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.62
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 7.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.26]
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  7.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.06]
# |   |   |   |   |   |   |   |   |   |--- Latitude >  33.62
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 7.86
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.25]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  7.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- Latitude >  37.69
# |   |   |   |   |   |   |   |   |--- HouseAge <= 20.50
# |   |   |   |   |   |   |   |   |   |--- AveOccup <= 2.33
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.99]
# |   |   |   |   |   |   |   |   |   |--- AveOccup >  2.33
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 37.77
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.35]
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  37.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- HouseAge >  20.50
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 8.18
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 7.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.67]
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  7.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.80]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  8.18
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 1689.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Population >  1689.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.58]
# |   |   |   |   |   |--- AveOccup >  2.78
# |   |   |   |   |   |   |--- AveBedrms <= 1.13
# |   |   |   |   |   |   |   |--- Population <= 1856.50
# |   |   |   |   |   |   |   |   |--- Population <= 1829.00
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 8.01
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 818.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Population >  818.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- MedInc >  8.01
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 8.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  8.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- Population >  1829.00
# |   |   |   |   |   |   |   |   |   |--- value: [1.94]
# |   |   |   |   |   |   |   |--- Population >  1856.50
# |   |   |   |   |   |   |   |   |--- Longitude <= -117.83
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 7.04
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 2139.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.77]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  2139.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  7.04
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- Longitude >  -117.83
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 33.57
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.35]
# |   |   |   |   |   |   |   |   |   |--- Latitude >  33.57
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 3662.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Population >  3662.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- AveBedrms >  1.13
# |   |   |   |   |   |   |   |--- AveOccup <= 3.06
# |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |--- AveOccup >  3.06
# |   |   |   |   |   |   |   |   |--- AveRooms <= 8.68
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |--- AveRooms >  8.68
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |--- HouseAge >  28.50
# |   |   |   |   |   |--- AveBedrms <= 1.00
# |   |   |   |   |   |   |--- Longitude <= -117.99
# |   |   |   |   |   |   |   |--- Latitude <= 37.86
# |   |   |   |   |   |   |   |   |--- MedInc <= 7.84
# |   |   |   |   |   |   |   |   |   |--- value: [3.80]
# |   |   |   |   |   |   |   |   |--- MedInc >  7.84
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.82]
# |   |   |   |   |   |   |   |--- Latitude >  37.86
# |   |   |   |   |   |   |   |   |--- Longitude <= -122.40
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 5.83
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.63]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  5.83
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 1274.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  1274.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.71]
# |   |   |   |   |   |   |   |   |--- Longitude >  -122.40
# |   |   |   |   |   |   |   |   |   |--- Latitude <= 37.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.34]
# |   |   |   |   |   |   |   |   |   |--- Latitude >  37.90
# |   |   |   |   |   |   |   |   |   |   |--- Population <= 509.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.06]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  509.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Longitude >  -117.99
# |   |   |   |   |   |   |   |--- Longitude <= -117.89
# |   |   |   |   |   |   |   |   |--- value: [3.52]
# |   |   |   |   |   |   |   |--- Longitude >  -117.89
# |   |   |   |   |   |   |   |   |--- value: [3.20]
# |   |   |   |   |   |--- AveBedrms >  1.00
# |   |   |   |   |   |   |--- AveOccup <= 3.24
# |   |   |   |   |   |   |   |--- Longitude <= -117.08
# |   |   |   |   |   |   |   |   |--- Latitude <= 37.49
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 6.21
# |   |   |   |   |   |   |   |   |   |   |--- Latitude <= 34.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Latitude >  34.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.16]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  6.21
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.19
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.60]
# |   |   |   |   |   |   |   |   |--- Latitude >  37.49
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.03
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 7.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  7.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  1.03
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -122.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -122.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.90]
# |   |   |   |   |   |   |   |--- Longitude >  -117.08
# |   |   |   |   |   |   |   |   |--- value: [3.80]
# |   |   |   |   |   |   |--- AveOccup >  3.24
# |   |   |   |   |   |   |   |--- value: [2.82]
# |   |   |   |--- MedInc >  8.87
# |   |   |   |   |--- Population <= 56.50
# |   |   |   |   |   |--- Population <= 33.50
# |   |   |   |   |   |   |--- HouseAge <= 41.00
# |   |   |   |   |   |   |   |--- Latitude <= 37.44
# |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |--- Latitude >  37.44
# |   |   |   |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |   |   |--- HouseAge >  41.00
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |--- Population >  33.50
# |   |   |   |   |   |   |--- Longitude <= -121.99
# |   |   |   |   |   |   |   |--- Population <= 43.50
# |   |   |   |   |   |   |   |   |--- value: [2.25]
# |   |   |   |   |   |   |   |--- Population >  43.50
# |   |   |   |   |   |   |   |   |--- value: [2.81]
# |   |   |   |   |   |   |--- Longitude >  -121.99
# |   |   |   |   |   |   |   |--- Longitude <= -119.90
# |   |   |   |   |   |   |   |   |--- value: [1.31]
# |   |   |   |   |   |   |   |--- Longitude >  -119.90
# |   |   |   |   |   |   |   |   |--- value: [1.12]
# |   |   |   |   |--- Population >  56.50
# |   |   |   |   |   |--- Latitude <= 38.15
# |   |   |   |   |   |   |--- HouseAge <= 20.50
# |   |   |   |   |   |   |   |--- MedInc <= 10.92
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 0.96
# |   |   |   |   |   |   |   |   |   |--- AveBedrms <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms <= 6.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AveRooms >  6.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- AveBedrms >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -120.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.26]
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -120.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- AveBedrms >  0.96
# |   |   |   |   |   |   |   |   |   |--- Longitude <= -118.10
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- HouseAge >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Longitude >  -118.10
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 10.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  10.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- MedInc >  10.92
# |   |   |   |   |   |   |   |   |--- Longitude <= -122.15
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 8.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  8.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.93]
# |   |   |   |   |   |   |   |   |--- Longitude >  -122.15
# |   |   |   |   |   |   |   |   |   |--- AveRooms <= 10.19
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.83
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- AveRooms >  10.19
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup <= 4.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.32]
# |   |   |   |   |   |   |   |   |   |   |--- AveOccup >  4.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.83]
# |   |   |   |   |   |   |--- HouseAge >  20.50
# |   |   |   |   |   |   |   |--- AveOccup <= 5.35
# |   |   |   |   |   |   |   |   |--- Longitude <= -117.13
# |   |   |   |   |   |   |   |   |   |--- MedInc <= 10.32
# |   |   |   |   |   |   |   |   |   |   |--- MedInc <= 10.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- MedInc >  10.31
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |   |   |--- MedInc >  10.32
# |   |   |   |   |   |   |   |   |   |   |--- Longitude <= -117.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Longitude >  -117.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Longitude >  -117.13
# |   |   |   |   |   |   |   |   |   |--- value: [3.91]
# |   |   |   |   |   |   |   |--- AveOccup >  5.35
# |   |   |   |   |   |   |   |   |--- AveBedrms <= 1.16
# |   |   |   |   |   |   |   |   |   |--- value: [1.82]
# |   |   |   |   |   |   |   |   |--- AveBedrms >  1.16
# |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |--- Latitude >  38.15
# |   |   |   |   |   |   |--- Longitude <= -121.49
# |   |   |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |   |   |--- Longitude >  -121.49
# |   |   |   |   |   |   |   |--- value: [3.12]

# %% [markdown]
# A bit overwhelming to see, let's use graphviz library.
#
# **Note**: you will need to install graphivz - pip install graphviz

# %% [markdown]
# - We will train a decision tree, in this case with max_depth=2 to better see the diagram

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\sabinafirtala\anaconda3\envs\lizzy_dev\lib\site-packages (0.20.3)

# %%
#your code here
from sklearn.tree import DecisionTreeRegressor, export_graphviz
import graphviz

tree = DecisionTreeRegressor(max_depth=2)
tree.fit(X_train_norm, y_train)


dot_data = export_graphviz(tree, out_file="tree.dot", filled=True, rounded=True, feature_names=dt.feature_names_in_)

with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\backend\execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\backend\execute.py:96, in _run_input_lines(cmd, input_lines, kwargs)
#      95 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 96     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#      98     stdin_write = popen.stdin.write
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\subprocess.py:1022, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1019             self.stderr = io.TextIOWrapper(self.stderr,
#    1020                     encoding=encoding, errors=errors)
# -> 1022     self._execute_child(args, executable, preexec_fn, close_fds,
#    1023                         pass_fds, cwd, env,
#    1024                         startupinfo, creationflags, shell,
#    1025                         p2cread, p2cwrite,
#    1026                         c2pread, c2pwrite,
#    1027                         errread, errwrite,
#    1028                         restore_signals,
#    1029                         gid, gids, uid, umask,
#    1030                         start_new_session, process_group)
#    1031 except:
#    1032     # Cleanup if the child failed starting.
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\subprocess.py:1491, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1490 try:
# -> 1491     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1492                              # no special security
#    1493                              None, None,
#    1494                              int(not close_fds),
#    1495                              creationflags,
#    1496                              env,
#    1497                              cwd,
#    1498                              startupinfo)
#    1499 finally:
#    1500     # Child is launched. Close the parent's copy of those pipe
#    1501     # handles that only the child should have open.  You need
#    (...)
#    1504     # pipe will not close when the child process exits and the
#    1505     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\IPython\core\formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\jupyter_integration.py:98, in <dictcomp>(.0)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\backend\piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File c:\Users\SabinaFirtala\anaconda3\envs\lizzy_dev\Lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
